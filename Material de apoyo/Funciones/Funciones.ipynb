# %%
"""
  Función : def nombreFuncion(valores): 
"""
def picoyCedula(n):
  return n%2==0

picoyCedula(32485789)
# Out:
# False

# %%
def operacionSuma (a,b):
  suma = a+b
  return suma

valor = operacionSuma(4,3)

print(valor)
# Out:
# 7

# %%
def operacionSuma (a,b):
  suma = a+b
  print(suma) 
operacionSuma(4,3)
# Out:
# 7

# %%
def factorial(numero):
  fact = 1
  for i in range (1,numero+1):
    fact = fact * i
  print(numero, fact)
  return fact


def combinatoria(n,m):
  factN = factorial(n)#5
  factM = factorial(m)#3
  factNM = factorial(n-m)#2
  resultado = factN / (factM * factNM)
  print(resultado)

combinatoria(5,3)
# Out:
# 5 120
# 3 6
# 2 2
# 10.0
